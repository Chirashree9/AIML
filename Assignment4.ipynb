# %%
import matplotlib.pyplot as plt
X = range(1, 50)
Y = [value * 3 for value in X]
plt.plot(X, Y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Line graph.')
plt.show()

# %%
import matplotlib.pyplot as plt
with open("test.txt") as f:
    data = f.read()
data = data.strip().split('\n')
x = [float(row.split(' ')[0]) for row in data]
y = [float(row.split(' ')[1]) for row in data]
plt.plot(x, y, marker='o', linestyle='-', color='b')
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Graph!')
#plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data.csv', sep=',', parse_dates=True, index_col=0)
df.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
x1 = [10,20,30]
y1 = [20,40,10]
plt.plot(x1, y1, label = "line 1")
x2 = [10,20,30]
y2 = [40,10,30]
plt.plot(x2, y2, label = "line 2")
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend()
plt.show()

# %%
import pandas as pd
l1 = list(map(int,input("Enter array elements separated by spaces: ").split()))
ds = pd.Series(l1)
print(ds)
# Out:
# Enter array elements separated by spaces: 2 4 6 8 10
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
import pandas as pd
ds = pd.Series([2, 4, 6, 8, 10])
print("Pandas Series and type")
print(ds)
print(type(ds))
print("Convert Pandas Series to Python list")
print(ds.tolist())
print(type(ds.tolist()))
# Out:
# Pandas Series and type
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# <class 'pandas.core.series.Series'>
# Convert Pandas Series to Python list
# [2, 4, 6, 8, 10]
# <class 'list'>

# %%
import pandas as pd
l1 = list(map(int,input("Enter first list elements separated by spaces: ").split()))
l2 = list(map(int,input("Enter second list elements separated by spaces: ").split()))
ds1=pd.Series(l1)
ds2=pd.Series(l2)
ds = ds1 + ds2
print("Add two Series:")
print(ds)
print("Subtract two Series:")
ds = ds1 - ds2
print(ds)
print("Multiply two Series:")
ds = ds1 * ds2
print(ds)
print("Divide Series1 by Series2:")
ds = ds1 / ds2
print(ds)
# Out:
# Enter first list elements separated by spaces: 2 4 6 8 10
# Enter second list elements separated by spaces: 1 3 5 7 9
# Add two Series:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64
# Subtract two Series:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64
# Multiply two Series:
# 0     2
# 1    12
# 2    30
# 3    56
# 4    90
# dtype: int64
# Divide Series1 by Series2:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.111111
# dtype: float64

# %%
import pandas as pd
l1 = list(map(int,input("Enter first list elements separated by spaces: ").split()))
l2 = list(map(int,input("Enter second list elements separated by spaces: ").split()))
ds1=pd.Series(l1)
ds2=pd.Series(l2)
print("Series1:")
print(ds1)
print("Series2:")
print(ds2)
print("Compare the elements of the said Series:")
print("Equals:")
print(ds1 == ds2)
print("Greater than:")
print(ds1 > ds2)
print("Less than:")
print(ds1 < ds2)
# Out:
# Enter first list elements separated by spaces: 2 4 6 8 10
# Enter second list elements separated by spaces: 1 3 5 7 9
# Series1:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# Series2:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
# Compare the elements of the said Series:
# Equals:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# Greater than:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool
# Less than:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
import pandas as pd
empno=int(input("Enter employee no:"))
ename=input("Enter employee name: ")
basic=int(input("Enter basic: "))
d1 = {"empno":empno,"ename":ename,"basic":basic}
print("Original dictionary:")
print(d1)
new_series = pd.Series(d1)
print("Converted series:")
print(new_series)
# Out:
# Enter employee no:101
# Enter employee name: ann
# Enter basic: 3000
# Original dictionary:
# {'empno': 101, 'ename': 'ann', 'basic': 3000}
# Converted series:
# empno     101
# ename     ann
# basic    3000
# dtype: object

# %%
import numpy as np
import pandas as pd
np_array = np.array([10, 20, 30, 40, 50])
print("NumPy array:")
print(np_array)
new_series = pd.Series(np_array)
print("Converted Pandas series:")
print(new_series)
# Out:
# NumPy array:
# [10 20 30 40 50]
# Converted Pandas series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)  
Y = np.array([1.5, 3.8, 6.7, 9.0, 11.2, 13.6, 16])


model = LinearRegression()
model.fit(X, Y)

Y_pred = model.predict(X)


mse = mean_squared_error(Y, Y_pred)

print("Slope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)
print("Mean Squared Error (MSE):", mse)

print("Predicted values:", Y_pred)
# Out:
# Slope (m): 2.4142857142857133
# Intercept (b): -0.8285714285714239
# Mean Squared Error (MSE): 0.024081632653061246
# Predicted values: [ 1.58571429  4.          6.41428571  8.82857143 11.24285714 13.65714286
#  16.07142857]
